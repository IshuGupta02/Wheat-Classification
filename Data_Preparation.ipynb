# %%
import tensorflow as tf

# %%
from tensorflow import keras as keras
from keras import layers as layers
import numpy as np

# %%
import os
import cv2
from skimage.filters import threshold_otsu
import matplotlib.pyplot as plt
from math import inf as inf
import numpy as np

# %%
from spectral.io import envi as envi
from spectral import imshow

# %%
from sklearn.decomposition import IncrementalPCA

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
from sys import platform
DATA_DIRECTORY = ""

if platform == "linux" or platform == "linux2":
    DATA_DIRECTORY = "\mnt\\"
elif platform == "win32":
    DATA_DIRECTORY = "D:\mvl\wheat\data\BULK\\"

# %%
#Testing Constants
TESTING = False

#Constants
BAND_NUMBER = 60
FILLED_AREA_RATIO = 0.7
IMAGE_COUNT = 30
NUM_VARIETIES = 6

# %%
def exactPathHDR(variety,file):
    return DATA_DIRECTORY+variety+"\\"+file+".bil.hdr"

def exactPathBIL(variety,file):
    return DATA_DIRECTORY+variety+"\\"+file+".bil"

# %%
def getROI(img,band_number):
    img_band = img.read_band(band_number)
    threshold = threshold_otsu(img_band)
    roi=[]
    for x in range(img_band.shape[0]):
        a=[]
        for y in range(img_band.shape[1]):
            if img_band[x][y]>threshold:
                a.append(1)
            else:
                a.append(0)
        roi.append(a)
    return roi

# %%
#Returns range for x and y from where we have to crop images
def getRangeXandY(img,band_number):
    img_band = img.read_band(band_number)
    roi = getROI(img,band_number)
    xmin = inf
    xmax = 0
    ymin = inf
    ymax = 0
    for x in range(img_band.shape[0]):
        for y in range(img_band.shape[1]):
            if roi[x][y]==1:
                if x<xmin:
                    xmin=x
                if x>xmax:
                    xmax=x
                if y<ymin:
                    ymin=y
                if y>ymax:
                    ymax=y
    return xmin, xmax, ymin, ymax

# %%
def getCroppedImage(img,band_number):
    xmin, xmax, ymin, ymax = getRangeXandY(img,band_number)
    new_img = img[xmin:xmax, ymin:ymax, :]
    return new_img

# %%
def getCroppedROI(img,band_number):
    xmin, xmax, ymin, ymax = getRangeXandY(img,band_number)
    roi = np.array(getROI(img,band_number))
    roi = roi[xmin:xmax, ymin:ymax]
    return roi

# %%
def getUsefulImage(img,band_number):
    crop_img = getCroppedImage(img,band_number)
    crop_roi = getCroppedROI(img,band_number)
    for x in range(crop_img.shape[2]):
        band = crop_img[:,:,x]
        crop_img[:,:,x] = band*crop_roi
    return crop_img

# %%
data_augmentation = keras.Sequential([
    layers.RandomCrop(height=40, width=40),
    layers.RandomRotation(factor=(-0.1, 0.1)),
    layers.RandomZoom(height_factor=(-0.1, 0.1), width_factor=(-0.1,0.1)),
])

def getAugumentedImage(img,band_number):
    new_img = getUsefulImage(img,band_number)
    augmented_image = data_augmentation(new_img) 
    return augmented_image

def checkAugumentedImage(augmented_image):
    aug_band = augmented_image[:,:,0]
    filled_area_ratio = (np.count_nonzero(aug_band))/(aug_band.shape[0]*aug_band.shape[1])
    if filled_area_ratio > FILLED_AREA_RATIO :
        return True
    else:
        return False

# %%
## Dimensional Reduction Method
def DL_Method(HSI, numComponents = 75):
    RHSI = np.reshape(HSI, (-1, HSI.shape[2]))
    n_batches = 10
    inc_pca = IncrementalPCA(n_components=numComponents)
    for X_batch in np.array_split(RHSI, n_batches):
        inc_pca.partial_fit(X_batch)
    X_ipca = inc_pca.transform(RHSI)
    RHSI = np.reshape(X_ipca, (HSI.shape[0],HSI.shape[1], numComponents))
    return RHSI

# %%
# List for All varieties
VARIETIES = []
VARIETIES_CODE = {}

for name in os.listdir(DATA_DIRECTORY):
    if (name.endswith(".hdr") or name.endswith(".bil")):
        continue
    VARIETIES_CODE[name] = len(VARIETIES)
    VARIETIES.append(name)
    if len(VARIETIES)==NUM_VARIETIES:
        break

# %%
#List for all file names in varities
FILES = []
MAX_FILE_NUM = 4
for x in range(1,MAX_FILE_NUM+1):
    FILES.append("B_"+str(x))

# %%
#List of all images
images = []
images_label = []
for v in VARIETIES:
    for f in FILES:
        try:
            img = envi.open(exactPathHDR(v,f),exactPathBIL(v,f))
            images.append(img)
            images_label.append(v)
        except:
            pass

# %%
train_dataset = []
train_dataset_label = []
test_dataset = []
test_dataset_label = []

for index, img in enumerate(images):
    count = 0
    label = images_label[index]
    while count<IMAGE_COUNT:
        aug_img = getAugumentedImage(img,BAND_NUMBER)
        
        if checkAugumentedImage(aug_img):
            aug_img = DL_Method(aug_img[:,:,21:150])
            if count%5 == 0:
                test_dataset.append(aug_img)
                test_dataset_label.append(label)
            else:
                train_dataset.append(aug_img)
                train_dataset_label.append(label)
            count+=1  
            
    if TESTING:
        break
# Out:
# C:\Users\ganga\anaconda3\envs\tensorflow-gpu\lib\site-packages\sklearn\decomposition\_incremental_pca.py:337: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ratio = S**2 / np.sum(col_var * n_total_samples)

# %%
for index,data in enumerate(test_dataset):
#     imshow(data)
    print(test_dataset_label[index])
# Out:
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat

# %%
for index,data in enumerate(train_dataset):
#     imshow(data)
    print(train_dataset_label[index])
# Out:
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW 187
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# DBW222
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# HD 3086
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 291
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat
# PBW 343 Unnat

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot as plt
# import math, sys, pdb, os
import keras
import keras.backend as K
import tensorflow as tf
from keras.layers import Input, Conv2D, MaxPooling2D, Activation, BatchNormalization, Add, Conv2DTranspose, Flatten, Dense, Conv1D, AveragePooling2D, LeakyReLU, PReLU, GlobalAveragePooling2D
from keras.layers.core import Dropout
from keras.layers import concatenate
from keras.models import Model

import os, pdb, timeit
import numpy as np
from keras.callbacks import TensorBoard
from keras.optimizers import Adam
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt

from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
import matplotlib.cm as cm
import cv2
from keras import activations
import vis
# from vis.visualization import visualize_saliency, overlay
# from vis.utils import utils

# %%
def normalizeDataWholeSeed(data,normalization_type='max'):
    
    if normalization_type == 'max':
        for idx in range(data.shape[0]):
            data[idx,:,:,:] = data[idx,:,:,:]/np.max(abs(data[idx,:,:,:]))
            
    elif normalization_type == 'l2norm':
        from numpy import linalg as LA
        for idx in range(data.shape[0]):
            data[idx,:,:,:] = data[idx,:,:,:]/LA.norm(data[idx,:,:,:]) # L2-norm by default        
        
    return data

# %%
def make_hyperparam_string(USE_DATA_AUG, learning_rate_base, batch_size, kernel_size, dropout_rate, num_training,
                           num_nodes_fc, activation_type):
    hparam = ""

    # Hyper-parameters
    if USE_DATA_AUG:
        hparam += "AUG_"

    hparam += str(num_nodes_fc) + "nodes_" + str(learning_rate_base) + "lr_" + str(batch_size) + "batch_" + str(
        kernel_size) + "kernel_" + str(dropout_rate) + "drop_" + str(
        num_training) + "train_" + activation_type

    return hparam

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    import itertools
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.clim(0,sum(cm[0,:]))
    plt.xlabel('Predicted label')

# %%
def top_K_classification_accuracy(y_predicted, y_true, K=1):

    num_samples = y_predicted.shape[0]
    num_classes = y_predicted.shape[1]

    if K > num_classes:
        sys.exit(1)

    temp = np.zeros((num_samples,))

    for idx in range(num_samples):
        curr_predicted = np.argsort(y_predicted[idx,:])
        curr_predicted = curr_predicted[::-1] # descending

        if y_true[idx] in curr_predicted[:K]:
            temp[idx] = 1

    return 100.0 * np.sum(temp)/num_samples

# %%
def conv2D_ResNet(x, kernel_size, activation_type, dropout_rate, num_filters_first_conv1D):

    x_orig = x

    # Batch norm
    x = BatchNormalization()(x)

    # 1x1 Conv2D
    x = Conv2D(num_filters_first_conv1D, kernel_size=1, activation=None, use_bias=False, padding='same',
               kernel_initializer='truncated_normal')(x)

    # Activation
    if activation_type == 'LeakyReLU':
        x = LeakyReLU()(x)
    elif activation_type == 'PReLU':
        x = PReLU()(x)
    else:
        x = Activation(activation_type)(x)

    x = BatchNormalization()(x)

    # 3x3 Conv2D
    x = Conv2D(num_filters_first_conv1D, kernel_size, activation=None, use_bias=True, padding='same',
               kernel_initializer='truncated_normal')(x)

    # Activation
    if activation_type == 'LeakyReLU':
        x = LeakyReLU()(x)
    elif activation_type == 'PReLU':
        x = PReLU()(x)
    else:
        x = Activation(activation_type)(x)

    x = BatchNormalization()(x)

    # 1x1 Conv2D
    x = Conv2D(num_filters_first_conv1D*4, kernel_size=1, activation=None, use_bias=False, padding='same',
               kernel_initializer='truncated_normal')(x)

    # Skip connection
    if int(x.shape[3]) != int(x_orig.shape[3]):
        x_orig = Conv2D(int(x.shape[3]), kernel_size=1, activation=None, use_bias=False, padding='same',
               kernel_initializer='truncated_normal')(x_orig)

    # Activation
    if activation_type == 'LeakyReLU':
        x = LeakyReLU()(x)
    elif activation_type == 'PReLU':
        x = PReLU()(x)
    else:
        x = Activation(activation_type)(x)

    x = Add()([x, x_orig])

    # Dropout
    return Dropout(dropout_rate)(x)

# %%
def createBlock_ResNet2D(x, num_layers, kernel_size, activation_type, dropout_rate, num_filters_first_conv1D):

    for idx_layer in range(num_layers):

        x = conv2D_ResNet(x, kernel_size, activation_type, dropout_rate, num_filters_first_conv1D)

    return x

# %%
# growth_rate: number of filters for each normal convolution ('k' in the paper)
def ResNet2D_classifier(data_num_rows, data_num_cols, num_classes, kernel_size=3, num_layers_each_block=[6, 12, 24, 16],
                        num_chan_per_block = [64,128,256,512], activation_type='swish', dropout_rate=0.0, num_input_chans=1, num_nodes_fc=64):

    input_data = Input(shape=(data_num_rows, data_num_cols, num_input_chans))

    # Input layer: Conv2D -> activation
    x = Conv2D(num_chan_per_block[0], kernel_size, activation=None, use_bias=True, padding='same',
               kernel_initializer='truncated_normal')(input_data)

    # Activation
    if activation_type == 'LeakyReLU':
        x = LeakyReLU()(x)
    elif activation_type == 'PReLU':
        x = PReLU()(x)
    else:
        x = Activation(activation_type)(x)

    #  Blocks & Downsampling Layers
    for idx_block in range(len(num_layers_each_block)):
        x = createBlock_ResNet2D(x, num_layers_each_block[idx_block], kernel_size, activation_type, dropout_rate,
                                 num_chan_per_block[idx_block])

        x = BatchNormalization()(x)

        if idx_block != len(num_layers_each_block)-1:
            x = Conv2D(num_chan_per_block[idx_block]*2, kernel_size, strides = 2, activation=None, use_bias=True, padding='valid',
                   kernel_initializer='truncated_normal')(x)
        else:
            x = GlobalAveragePooling2D()(x)

        x = Dropout(dropout_rate)(x)

    # Output layer
    x = BatchNormalization()(x)
    x = Dense(units=num_nodes_fc, activation=None, kernel_initializer='truncated_normal')(x)

    # Activation
    if activation_type == 'LeakyReLU':
        x = LeakyReLU()(x)
    elif activation_type == 'PReLU':
        x = PReLU()(x)
    else:
        x = Activation(activation_type)(x)

    x = BatchNormalization()(x)
    output_data = Dense(units=num_classes, activation='softmax', kernel_initializer='truncated_normal')(x)

    return Model(inputs=input_data, outputs=output_data)

# %%
def evaluate(model, normalization_type='max'):
    print("--------------Make Predictions--------------")
    # In this example script, we use the training data as the test data
    
    x_train = np.array(train_dataset)
    labels_train = np.array(train_dataset_label)
    labels_train = [VARIETIES_CODE[label] for label in labels_train]
    
    # Normalize the data
    x_train = normalizeDataWholeSeed(x_train,normalization_type=normalization_type)
    
    num_train = x_train.shape[0]

    print("Testing for training data")
    tic = timeit.default_timer()
    labels_predicted_train = model.predict(x_train)
    toc = timeit.default_timer()
    test_time = toc - tic
    print('Testing time (s) = ' + str(test_time) + '\n')
    
    # Classification accuracy
    labels_train_integer_format = labels_train
    labels_predicted_train_integer_format = np.argmax(labels_predicted_train, axis=1)

    acc_top2 = top_K_classification_accuracy(labels_predicted_train, labels_train_integer_format, K=2)
    acc_top1 = top_K_classification_accuracy(labels_predicted_train, labels_train_integer_format, K=1)
    
    # Confusion matrices
    confusion_matrix_results = confusion_matrix(labels_train_integer_format, labels_predicted_train_integer_format)
    print("Confusion matrix = ")
    print(confusion_matrix_results)
    
    print("---------------------------------------------")
    # Load Testing data and their corresponding labels
    x_test = np.array(test_dataset)
    labels_test = np.array(test_dataset_label)
    labels_test = [VARIETIES_CODE[label] for label in labels_test]
    
    # Normalize the data
    x_test = normalizeDataWholeSeed(x_test,normalization_type=normalization_type)
    num_test = x_test.shape[0]
    
    print("Testing for test data")
    tic = timeit.default_timer()
    labels_predicted_test = model.predict(x_test)
    toc = timeit.default_timer()
    test_time = toc - tic
    print('Testing time (s) = ' + str(test_time) + '\n')
    ### Evaluation metrics

    # Classification accuracy
    labels_test_integer_format = labels_test
    labels_predicted_test_integer_format = np.argmax(labels_predicted_test, axis=1)

    acc_top2 = top_K_classification_accuracy(labels_predicted_test, labels_test_integer_format, K=2)
    acc_top1 = top_K_classification_accuracy(labels_predicted_test, labels_test_integer_format, K=1)
    
    # Confusion matrices
    confusion_matrix_results = confusion_matrix(labels_test_integer_format, labels_predicted_test_integer_format)
    print("Confusion matrix = ")
    print(confusion_matrix_results)
    
    # Precision, Recall, F1
#     macro_avg = np.asarray(
#         precision_recall_fscore_support(labels_test_integer_format, labels_predicted_test_integer_format,
#                                         average='macro'))
#     macro_avg_precision = macro_avg[0]
#     macro_avg_recall = macro_avg[1]
#     macro_avg_fscore = macro_avg[2]

#     print('Top-1 accuracy (%) = ' + str(acc_top1) + '\n')
#     print('Top-2 accuracy (%) = ' + str(acc_top2) + '\n')
#     print('Macro-avg precision = ' + str(macro_avg_precision) + '\n')
#     print('Macro-avg recall = ' + str(macro_avg_recall) + '\n')
#     print('Macro-avg f-score = ' + str(macro_avg_fscore) + '\n')

#     print("--------------Done--------------")

#     print("--------------Compute Saliency Maps--------------")
#     results_test_dir = os.path.join(results_dir, 'test')
#     if not os.path.exists(results_test_dir):
#         os.makedirs(results_test_dir)

#     # Swap softmax with linear
#     model.layers[-1].activation = activations.linear
#     model = utils.apply_modifications(model)

#     for idx_wheat in range(num_test):

#         grads = visualize_saliency(model, layer_idx=-1, filter_indices=np.argmax(labels_test[idx_wheat, :], axis=0),
#                                    seed_input=x_test[idx_wheat], backprop_modifier=None)

#         ss_img = np.sqrt(np.sum(abs(x_test[idx_wheat, :, :, :]) ** 2, axis=2))
#         ss_img /= np.max(ss_img)

#         plt.figure(1)
#         plt.subplot(3, 1, 1)
#         plt.imshow(ss_img, cmap='gray')
#         plt.clim(0, 1)
#         plt.axis('off')
#         plt.colorbar()

#         plt.subplot(3, 1, 2)
#         plt.imshow((grads * np.uint8(255)).astype('uint8'), cmap='jet')
#         plt.clim(0, 255)
#         plt.axis('off')
#         plt.colorbar()

#         jet_heatmap = np.uint8(cm.jet(grads)[..., :3] * np.uint8(255))

#         plt.subplot(3, 1, 3)
#         ss_img = cv2.cvtColor((ss_img * np.uint8(255)).astype('uint8'), cv2.COLOR_GRAY2RGB)
#         plt.imshow(overlay(jet_heatmap, ss_img, alpha=0.3))
#         plt.clim(0, 255)
#         plt.axis('off')
#         plt.colorbar()

#         plt.savefig(os.path.join(results_test_dir, str(idx_wheat+1) + '.png'))
#         plt.clf()

#     print("--------------Done--------------")

#     print("--------------Save the information--------------")

#     # Write some information to files
#     f = open(os.path.join(results_test_dir, 'testing_info.txt'), 'w')
#     f.write("Wheat types = " + str(wheat_types) + "\n")
#     f.write("Confusion matrix \n")
#     f.write(str(confusion_matrix_results) + "\n")
#     f.write("Normalization type = " + str(normalization_type) + "\n")
#     f.write("# test samples = %d \n" % (num_test))
#     f.write("Top-1 test accuracy = %f \n" % (acc_top1))
#     f.write("Top-2 test accuracy = %f \n" % (acc_top2))
#     f.write("Macro-avg precision = %f \n" % (macro_avg_precision))
#     f.write("Macro-avg recall = %f \n" % (macro_avg_recall))
#     f.write("Macro-avg f-score = %f \n" % (macro_avg_fscore))
#     f.write("Test time (s) = " + str(test_time) + "\n")
#     f.close()

#     # Save confusion matrices
#     plt.figure(1)
#     plot_confusion_matrix(confusion_matrix_results, classes=wheat_types, normalize=False, title='Confusion matrix')
#     plt.savefig(os.path.join(results_test_dir,'confusionMatrix.png'))
#     plt.clf()

#     print("--------------Done--------------")

#     print("--------------Save the information for the training phase--------------")
    
#     import pandas as pd
    
#     # Save the trained model
#     model.save_weights(os.path.join(results_dir, 'trainedResNetB_weights.h5'))
    
#     # Extract the training loss   
#     training_loss = hist.history['loss']

#     # Save the training loss
#     df = pd.DataFrame(data={'training loss': training_loss},index=np.arange(num_epochs)+1)
#     df.to_csv(os.path.join(results_dir,'training_loss.csv'))
    
#     # Save the training loss as a figure
#     plt.figure(1)
#     plt.title('Loss')
#     plt.plot(training_loss, color='b',label='Training')
#     plt.legend()
#     plt.grid()
#     plt.savefig(os.path.join(results_dir,'training_loss.png'))
#     plt.clf()   
    
#     # Write a file with general information
#     f = open(os.path.join(results_dir,'training_info.txt'),'w')
#     f.write(hparams + '\n')
#     f.write('Wheat types = ' + str(wheat_types)+'\n')
#     f.write('Training time (s) = %f \n' %(training_time))
#     f.write('Normalization type = ' + str(normalization_type)+ '\n')
#     f.write('# epochs = ' + str(num_epochs) + '\n')
#     f.write('# training samples = %d \n' %(num_training))
#     f.close()
    
#     print("--------------Done--------------")

# %%
def createAndTrainResNetB(params):
                                        
    ############ Extract params ############
    USE_DATA_AUG = params['USE_DATA_AUG']
    learning_rate_base = params['learning_rate_base']
    kernel_size = params['kernel_size']
    num_epochs = params['num_epochs']
    batch_size = params['batch_size']
    dropout_rate = params['dropout_rate']
    activation_type = params['activation_type']
    num_nodes_fc = params['num_nodes_fc']
    wheat_types = params['wheat_types']
    normalization_type = params['normalization_type']
    num_layers_each_block = params['num_layers_each_block']
    num_chan_per_block = params['num_chan_per_block']
    N_classes = len(wheat_types)
    
    
    ############ Load data ############
    print("--------------Load Data--------------")

    # Load training data and their corresponding labels
    x_training = np.array(train_dataset)
    labels_training = np.array(train_dataset_label)
    labels_training = [VARIETIES_CODE[label] for label in labels_training]
    
    # Normalize the data
    x_training = normalizeDataWholeSeed(x_training,normalization_type=normalization_type)
    
    # Extract some information
    num_training = x_training.shape[0]
    N_spatial = x_training.shape[1:3]
    N_bands = x_training.shape[3]
    num_batch_per_epoch = int(num_training/batch_size)
    
    print('#training = %d' %(num_training))
    print('#batches per epoch = %d' %(num_batch_per_epoch))
    
    print("--------------Done--------------")
    
    
    ############ Prepare the path for saving the models/stats ############
    print("--------------Prepare a path for saving the models/stats--------------")
    
    hparams = make_hyperparam_string(USE_DATA_AUG, learning_rate_base, batch_size, kernel_size, dropout_rate,
                                     num_training, num_nodes_fc, activation_type)
    print('Saving the model to...')
    
    results_dir = os.path.join(params['results_base_directory'],hparams)
    
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    print(results_dir)

    print("--------------Done--------------")

    ############ Create a model ############
    print("--------------Create a model--------------")
    
    # Generate a model
    model = ResNet2D_classifier(data_num_rows=N_spatial[0], data_num_cols=N_spatial[1], num_classes=N_classes,
                                kernel_size=kernel_size, num_layers_each_block=num_layers_each_block,
                                num_chan_per_block=num_chan_per_block, activation_type=activation_type,
                                dropout_rate=dropout_rate, num_input_chans=N_bands, num_nodes_fc=num_nodes_fc)

    # Compile the model
    adam_opt = Adam(lr=learning_rate_base / batch_size, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.01)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=adam_opt, metrics=['acc'])

    # Create a Tensorboard callback
    tbCallBack = TensorBoard(log_dir=results_dir, histogram_freq=0, write_graph=False, write_images=False)
    
    print("--------------Done--------------")

    ############ Train the model ############
    print("--------------Begin training the model--------------")

    # Possibly perform data augmentation
    from keras.preprocessing.image import ImageDataGenerator
    
    if USE_DATA_AUG:
        width_shift_range = 0.04
        height_shift_range = 0.04
        HORIZONTAL_FLIP = True
        VERTICAL_FLIP = True
        data_gen_args = dict(
            rotation_range=0.,
            width_shift_range=width_shift_range,
            height_shift_range=height_shift_range,
            horizontal_flip=HORIZONTAL_FLIP,
            vertical_flip=VERTICAL_FLIP,
            fill_mode = 'wrap')

        image_datagen = ImageDataGenerator(**data_gen_args)
    else:
        image_datagen = ImageDataGenerator()

    # Define a data generator to generate random batches
    def myGenerator(batch_size):
        for x_batch, y_batch in image_datagen.flow(x_training, labels_training, batch_size=batch_size, shuffle = True):
            yield (x_batch, y_batch)

    my_generator = myGenerator(batch_size)
#     validation_generator = myGenerator(batch_size, subset='validation')

    tic = timeit.default_timer()
    
    # Train the model
    hist = model.fit(my_generator, steps_per_epoch=num_batch_per_epoch, epochs = num_epochs, initial_epoch = 0, verbose=2, callbacks = [tbCallBack])

    toc = timeit.default_timer()
    training_time = toc-tic
    print("Total training time = " + str(training_time))
    
    print("--------------Done--------------")

    return model

# %%
# Parameters (mostly determined using validation datasets)
params = dict()
params['normalization_type'] = 'max'                    # Data normalization type
params['wheat_types'] = VARIETIES
params['num_epochs'] = 20                              # Number of epochs
params['kernel_size'] = 3                               # Kernel size
params['dropout_rate'] = 0.0                            # Dropout rate
params['num_nodes_fc'] = 512                            # Number of  nodes in the fully-connected layers
params['num_layers_each_block'] = [8, 8, 12, 8]         # Number of layers per block
params['num_chan_per_block'] = [128, 128, 256, 256]     # Number of filters in the conv layers
params['results_base_directory'] = './results/'  # Directory of saving results
params['activation_type'] = 'ReLU'
# In our experiment where we have the full training set, we set
# USE_DATA_AUG = True, learning_rate_base = 0.005, and batch_size = 4.
# However, in this example script, we modified them to simplify our training process on this
# example dataset
params['batch_size'] = 5                    # Batch size
params['USE_DATA_AUG'] = False              # Use data augmentation (In the paper, we set it to True)
params['learning_rate_base'] = 0.0001      # Initial learning rate (In the paper, we set it to 0.005)

# Add 'swish' activation
if params['activation_type'] == 'swish':

    from tensorflow.keras.utils import get_custom_objects
    import keras.backend as K

    # Taken from https://github.com/dataplayer12/swish-activation/blob/master/MNIST/activations.ipynb
    def swish(x):
        beta = tf.Variable(initial_value=1.0,trainable=True)
        return x*tf.nn.sigmoid(beta*x)

    get_custom_objects().update({'swish': swish})

# %%
model = createAndTrainResNetB(params)
# Out:
# --------------Load Data--------------
# #training = 576
# #batches per epoch = 115
# --------------Done--------------
# --------------Prepare a path for saving the models/stats--------------
# Saving the model to...
# ./results/512nodes_0.0001lr_5batch_3kernel_0.0drop_576train_ReLU
# --------------Done--------------
# --------------Create a model--------------
# --------------Done--------------
# --------------Begin training the model--------------
# C:\Users\ganga\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\preprocessing\image.py:766: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (576, 40, 40, 75) (75 channels).
#   warnings.warn(
# Epoch 1/20
# 115/115 - 426s - loss: 2.0783 - acc: 0.1930 - 426s/epoch - 4s/step
# Epoch 2/20
# 115/115 - 372s - loss: 1.6168 - acc: 0.3608 - 372s/epoch - 3s/step
# Epoch 3/20
# 115/115 - 400s - loss: 1.4457 - acc: 0.4203 - 400s/epoch - 3s/step
# Epoch 4/20
# 115/115 - 423s - loss: 1.3066 - acc: 0.5061 - 423s/epoch - 4s/step
# Epoch 5/20
# 115/115 - 436s - loss: 1.2278 - acc: 0.5674 - 436s/epoch - 4s/step
# Epoch 6/20
# 115/115 - 383s - loss: 1.1540 - acc: 0.5744 - 383s/epoch - 3s/step
# Epoch 7/20
# 115/115 - 384s - loss: 1.1103 - acc: 0.6270 - 384s/epoch - 3s/step
# Epoch 8/20
# 115/115 - 389s - loss: 1.1127 - acc: 0.5972 - 389s/epoch - 3s/step
# Epoch 9/20
# 115/115 - 377s - loss: 1.0541 - acc: 0.6410 - 377s/epoch - 3s/step
# Epoch 10/20
# 115/115 - 376s - loss: 1.0092 - acc: 0.6743 - 376s/epoch - 3s/step
# Epoch 11/20
# 115/115 - 381s - loss: 0.9951 - acc: 0.6637 - 381s/epoch - 3s/step
# Epoch 12/20
# 115/115 - 384s - loss: 0.9610 - acc: 0.7110 - 384s/epoch - 3s/step
# Epoch 13/20
# 115/115 - 375s - loss: 0.9150 - acc: 0.7198 - 375s/epoch - 3s/step
# Epoch 14/20
# 115/115 - 378s - loss: 0.9254 - acc: 0.7145 - 378s/epoch - 3s/step
# Epoch 15/20
# 115/115 - 380s - loss: 0.8873 - acc: 0.7215 - 380s/epoch - 3s/step
# Epoch 16/20
# 115/115 - 392s - loss: 0.8772 - acc: 0.7373 - 392s/epoch - 3s/step
# Epoch 17/20
# 115/115 - 397s - loss: 0.8790 - acc: 0.7356 - 397s/epoch - 3s/step
# Epoch 18/20
# 115/115 - 452s - loss: 0.8560 - acc: 0.7566 - 452s/epoch - 4s/step
# Epoch 19/20
# 115/115 - 454s - loss: 0.8022 - acc: 0.7898 - 454s/epoch - 4s/step
# Epoch 20/20
# 115/115 - 455s - loss: 0.8115 - acc: 0.7566 - 455s/epoch - 4s/step
# Total training time = 8019.932411100017
# --------------Done--------------

# %%
print(model.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 40, 40, 75)  0           []
#                                 ]
#
#  conv2d_348 (Conv2D)            (None, 40, 40, 128)  86528       ['input_4[0][0]']
#
#  activation_330 (Activation)    (None, 40, 40, 128)  0           ['conv2d_348[0][0]']
#
#  batch_normalization_342 (Batch  (None, 40, 40, 128)  512        ['activation_330[0][0]']
#  Normalization)
#
#  conv2d_349 (Conv2D)            (None, 40, 40, 128)  16384       ['batch_normalization_342[0][0]']
#
#  activation_331 (Activation)    (None, 40, 40, 128)  0           ['conv2d_349[0][0]']
#
#  batch_normalization_343 (Batch  (None, 40, 40, 128)  512        ['activation_331[0][0]']
#  Normalization)
#
#  conv2d_350 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_343[0][0]']
#
#  activation_332 (Activation)    (None, 40, 40, 128)  0           ['conv2d_350[0][0]']
#
#  batch_normalization_344 (Batch  (None, 40, 40, 128)  512        ['activation_332[0][0]']
#  Normalization)
#
#  conv2d_351 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_344[0][0]']
#
#  activation_333 (Activation)    (None, 40, 40, 512)  0           ['conv2d_351[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 40, 40, 512)  65536       ['activation_330[0][0]']
#
#  add_108 (Add)                  (None, 40, 40, 512)  0           ['activation_333[0][0]',
#                                                                   'conv2d_352[0][0]']
#
#  dropout_120 (Dropout)          (None, 40, 40, 512)  0           ['add_108[0][0]']
#
#  batch_normalization_345 (Batch  (None, 40, 40, 512)  2048       ['dropout_120[0][0]']
#  Normalization)
#
#  conv2d_353 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_345[0][0]']
#
#  activation_334 (Activation)    (None, 40, 40, 128)  0           ['conv2d_353[0][0]']
#
#  batch_normalization_346 (Batch  (None, 40, 40, 128)  512        ['activation_334[0][0]']
#  Normalization)
#
#  conv2d_354 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_346[0][0]']
#
#  activation_335 (Activation)    (None, 40, 40, 128)  0           ['conv2d_354[0][0]']
#
#  batch_normalization_347 (Batch  (None, 40, 40, 128)  512        ['activation_335[0][0]']
#  Normalization)
#
#  conv2d_355 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_347[0][0]']
#
#  activation_336 (Activation)    (None, 40, 40, 512)  0           ['conv2d_355[0][0]']
#
#  add_109 (Add)                  (None, 40, 40, 512)  0           ['activation_336[0][0]',
#                                                                   'dropout_120[0][0]']
#
#  dropout_121 (Dropout)          (None, 40, 40, 512)  0           ['add_109[0][0]']
#
#  batch_normalization_348 (Batch  (None, 40, 40, 512)  2048       ['dropout_121[0][0]']
#  Normalization)
#
#  conv2d_356 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_348[0][0]']
#
#  activation_337 (Activation)    (None, 40, 40, 128)  0           ['conv2d_356[0][0]']
#
#  batch_normalization_349 (Batch  (None, 40, 40, 128)  512        ['activation_337[0][0]']
#  Normalization)
#
#  conv2d_357 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_349[0][0]']
#
#  activation_338 (Activation)    (None, 40, 40, 128)  0           ['conv2d_357[0][0]']
#
#  batch_normalization_350 (Batch  (None, 40, 40, 128)  512        ['activation_338[0][0]']
#  Normalization)
#
#  conv2d_358 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_350[0][0]']
#  activation_339 (Activation)    (None, 40, 40, 512)  0           ['conv2d_358[0][0]']
#
#  add_110 (Add)                  (None, 40, 40, 512)  0           ['activation_339[0][0]',
#                                                                   'dropout_121[0][0]']
#
#  dropout_122 (Dropout)          (None, 40, 40, 512)  0           ['add_110[0][0]']
#
#  batch_normalization_351 (Batch  (None, 40, 40, 512)  2048       ['dropout_122[0][0]']
#  Normalization)
#
#  conv2d_359 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_351[0][0]']
#
#  activation_340 (Activation)    (None, 40, 40, 128)  0           ['conv2d_359[0][0]']
#
#  batch_normalization_352 (Batch  (None, 40, 40, 128)  512        ['activation_340[0][0]']
#  Normalization)
#
#  conv2d_360 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_352[0][0]']
#
#  activation_341 (Activation)    (None, 40, 40, 128)  0           ['conv2d_360[0][0]']
#
#  batch_normalization_353 (Batch  (None, 40, 40, 128)  512        ['activation_341[0][0]']
#  Normalization)
#
#  conv2d_361 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_353[0][0]']
#
#  activation_342 (Activation)    (None, 40, 40, 512)  0           ['conv2d_361[0][0]']
#
#  add_111 (Add)                  (None, 40, 40, 512)  0           ['activation_342[0][0]',
#                                                                   'dropout_122[0][0]']
#
#  dropout_123 (Dropout)          (None, 40, 40, 512)  0           ['add_111[0][0]']
#
#  batch_normalization_354 (Batch  (None, 40, 40, 512)  2048       ['dropout_123[0][0]']
#  Normalization)
#
#  conv2d_362 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_354[0][0]']
#
#  activation_343 (Activation)    (None, 40, 40, 128)  0           ['conv2d_362[0][0]']
#
#  batch_normalization_355 (Batch  (None, 40, 40, 128)  512        ['activation_343[0][0]']
#  Normalization)
#
#  conv2d_363 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_355[0][0]']
#
#  activation_344 (Activation)    (None, 40, 40, 128)  0           ['conv2d_363[0][0]']
#
#  batch_normalization_356 (Batch  (None, 40, 40, 128)  512        ['activation_344[0][0]']
#  Normalization)
#
#  conv2d_364 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_356[0][0]']
#
#  activation_345 (Activation)    (None, 40, 40, 512)  0           ['conv2d_364[0][0]']
#
#  add_112 (Add)                  (None, 40, 40, 512)  0           ['activation_345[0][0]',
#                                                                   'dropout_123[0][0]']
#
#  dropout_124 (Dropout)          (None, 40, 40, 512)  0           ['add_112[0][0]']
#
#  batch_normalization_357 (Batch  (None, 40, 40, 512)  2048       ['dropout_124[0][0]']
#  Normalization)
#
#  conv2d_365 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_357[0][0]']
#
#  activation_346 (Activation)    (None, 40, 40, 128)  0           ['conv2d_365[0][0]']
#
#  batch_normalization_358 (Batch  (None, 40, 40, 128)  512        ['activation_346[0][0]']
#  Normalization)
#
#  conv2d_366 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_358[0][0]']
#
#  activation_347 (Activation)    (None, 40, 40, 128)  0           ['conv2d_366[0][0]']
#
#  batch_normalization_359 (Batch  (None, 40, 40, 128)  512        ['activation_347[0][0]']
#  Normalization)
#
#  conv2d_367 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_359[0][0]']
#
#  activation_348 (Activation)    (None, 40, 40, 512)  0           ['conv2d_367[0][0]']
#
#  add_113 (Add)                  (None, 40, 40, 512)  0           ['activation_348[0][0]',
#                                                                   'dropout_124[0][0]']
#  dropout_125 (Dropout)          (None, 40, 40, 512)  0           ['add_113[0][0]']
#
#  batch_normalization_360 (Batch  (None, 40, 40, 512)  2048       ['dropout_125[0][0]']
#  Normalization)
#
#  conv2d_368 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_360[0][0]']
#
#  activation_349 (Activation)    (None, 40, 40, 128)  0           ['conv2d_368[0][0]']
#
#  batch_normalization_361 (Batch  (None, 40, 40, 128)  512        ['activation_349[0][0]']
#  Normalization)
#
#  conv2d_369 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_361[0][0]']
#
#  activation_350 (Activation)    (None, 40, 40, 128)  0           ['conv2d_369[0][0]']
#
#  batch_normalization_362 (Batch  (None, 40, 40, 128)  512        ['activation_350[0][0]']
#  Normalization)
#
#  conv2d_370 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_362[0][0]']
#
#  activation_351 (Activation)    (None, 40, 40, 512)  0           ['conv2d_370[0][0]']
#
#  add_114 (Add)                  (None, 40, 40, 512)  0           ['activation_351[0][0]',
#                                                                   'dropout_125[0][0]']
#
#  dropout_126 (Dropout)          (None, 40, 40, 512)  0           ['add_114[0][0]']
#
#  batch_normalization_363 (Batch  (None, 40, 40, 512)  2048       ['dropout_126[0][0]']
#  Normalization)
#
#  conv2d_371 (Conv2D)            (None, 40, 40, 128)  65536       ['batch_normalization_363[0][0]']
#
#  activation_352 (Activation)    (None, 40, 40, 128)  0           ['conv2d_371[0][0]']
#
#  batch_normalization_364 (Batch  (None, 40, 40, 128)  512        ['activation_352[0][0]']
#  Normalization)
#
#  conv2d_372 (Conv2D)            (None, 40, 40, 128)  147584      ['batch_normalization_364[0][0]']
#
#  activation_353 (Activation)    (None, 40, 40, 128)  0           ['conv2d_372[0][0]']
#
#  batch_normalization_365 (Batch  (None, 40, 40, 128)  512        ['activation_353[0][0]']
#  Normalization)
#
#  conv2d_373 (Conv2D)            (None, 40, 40, 512)  65536       ['batch_normalization_365[0][0]']
#
#  activation_354 (Activation)    (None, 40, 40, 512)  0           ['conv2d_373[0][0]']
#
#  add_115 (Add)                  (None, 40, 40, 512)  0           ['activation_354[0][0]',
#                                                                   'dropout_126[0][0]']
#
#  dropout_127 (Dropout)          (None, 40, 40, 512)  0           ['add_115[0][0]']
#
#  batch_normalization_366 (Batch  (None, 40, 40, 512)  2048       ['dropout_127[0][0]']
#  Normalization)
#
#  conv2d_374 (Conv2D)            (None, 19, 19, 256)  1179904     ['batch_normalization_366[0][0]']
#
#  dropout_128 (Dropout)          (None, 19, 19, 256)  0           ['conv2d_374[0][0]']
#
#  batch_normalization_367 (Batch  (None, 19, 19, 256)  1024       ['dropout_128[0][0]']
#  Normalization)
#
#  conv2d_375 (Conv2D)            (None, 19, 19, 128)  32768       ['batch_normalization_367[0][0]']
#
#  activation_355 (Activation)    (None, 19, 19, 128)  0           ['conv2d_375[0][0]']
#
#  batch_normalization_368 (Batch  (None, 19, 19, 128)  512        ['activation_355[0][0]']
#  Normalization)
#
#  conv2d_376 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_368[0][0]']
#
#  activation_356 (Activation)    (None, 19, 19, 128)  0           ['conv2d_376[0][0]']
#
#  batch_normalization_369 (Batch  (None, 19, 19, 128)  512        ['activation_356[0][0]']
#  Normalization)
#
#  conv2d_377 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_369[0][0]']
#
#  activation_357 (Activation)    (None, 19, 19, 512)  0           ['conv2d_377[0][0]']
#
#  conv2d_378 (Conv2D)            (None, 19, 19, 512)  131072      ['dropout_128[0][0]']
#
#  add_116 (Add)                  (None, 19, 19, 512)  0           ['activation_357[0][0]',
#                                                                   'conv2d_378[0][0]']
#
#  dropout_129 (Dropout)          (None, 19, 19, 512)  0           ['add_116[0][0]']
#
#  batch_normalization_370 (Batch  (None, 19, 19, 512)  2048       ['dropout_129[0][0]']
#  Normalization)
#
#  conv2d_379 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_370[0][0]']
#
#  activation_358 (Activation)    (None, 19, 19, 128)  0           ['conv2d_379[0][0]']
#
#  batch_normalization_371 (Batch  (None, 19, 19, 128)  512        ['activation_358[0][0]']
#  Normalization)
#
#  conv2d_380 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_371[0][0]']
#
#  activation_359 (Activation)    (None, 19, 19, 128)  0           ['conv2d_380[0][0]']
#
#  batch_normalization_372 (Batch  (None, 19, 19, 128)  512        ['activation_359[0][0]']
#  Normalization)
#
#  conv2d_381 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_372[0][0]']
#
#  activation_360 (Activation)    (None, 19, 19, 512)  0           ['conv2d_381[0][0]']
#
#  add_117 (Add)                  (None, 19, 19, 512)  0           ['activation_360[0][0]',
#                                                                   'dropout_129[0][0]']
#
#  dropout_130 (Dropout)          (None, 19, 19, 512)  0           ['add_117[0][0]']
#
#  batch_normalization_373 (Batch  (None, 19, 19, 512)  2048       ['dropout_130[0][0]']
#  Normalization)
#
#  conv2d_382 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_373[0][0]']
#
#  activation_361 (Activation)    (None, 19, 19, 128)  0           ['conv2d_382[0][0]']
#
#  batch_normalization_374 (Batch  (None, 19, 19, 128)  512        ['activation_361[0][0]']
#  Normalization)
#
#  conv2d_383 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_374[0][0]']
#
#  activation_362 (Activation)    (None, 19, 19, 128)  0           ['conv2d_383[0][0]']
#
#  batch_normalization_375 (Batch  (None, 19, 19, 128)  512        ['activation_362[0][0]']
#  Normalization)
#
#  conv2d_384 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_375[0][0]']
#
#  activation_363 (Activation)    (None, 19, 19, 512)  0           ['conv2d_384[0][0]']
#
#  add_118 (Add)                  (None, 19, 19, 512)  0           ['activation_363[0][0]',
#                                                                   'dropout_130[0][0]']
#
#  dropout_131 (Dropout)          (None, 19, 19, 512)  0           ['add_118[0][0]']
#
#  batch_normalization_376 (Batch  (None, 19, 19, 512)  2048       ['dropout_131[0][0]']
#  Normalization)
#
#  conv2d_385 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_376[0][0]']
#
#  activation_364 (Activation)    (None, 19, 19, 128)  0           ['conv2d_385[0][0]']
#
#  batch_normalization_377 (Batch  (None, 19, 19, 128)  512        ['activation_364[0][0]']
#  Normalization)
#
#  conv2d_386 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_377[0][0]']
#
#  activation_365 (Activation)    (None, 19, 19, 128)  0           ['conv2d_386[0][0]']
#
#  batch_normalization_378 (Batch  (None, 19, 19, 128)  512        ['activation_365[0][0]']
#  Normalization)
#
#  conv2d_387 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_378[0][0]']
#
#  activation_366 (Activation)    (None, 19, 19, 512)  0           ['conv2d_387[0][0]']
#
#  add_119 (Add)                  (None, 19, 19, 512)  0           ['activation_366[0][0]',
#                                                                   'dropout_131[0][0]']
#
#  dropout_132 (Dropout)          (None, 19, 19, 512)  0           ['add_119[0][0]']
#
#  batch_normalization_379 (Batch  (None, 19, 19, 512)  2048       ['dropout_132[0][0]']
#  Normalization)
#
#  conv2d_388 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_379[0][0]']
#
#  activation_367 (Activation)    (None, 19, 19, 128)  0           ['conv2d_388[0][0]']
#
#  batch_normalization_380 (Batch  (None, 19, 19, 128)  512        ['activation_367[0][0]']
#  Normalization)
#
#  conv2d_389 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_380[0][0]']
#
#  activation_368 (Activation)    (None, 19, 19, 128)  0           ['conv2d_389[0][0]']
#
#  batch_normalization_381 (Batch  (None, 19, 19, 128)  512        ['activation_368[0][0]']
#  Normalization)
#
#  conv2d_390 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_381[0][0]']
#
#  activation_369 (Activation)    (None, 19, 19, 512)  0           ['conv2d_390[0][0]']
#
#  add_120 (Add)                  (None, 19, 19, 512)  0           ['activation_369[0][0]',
#                                                                   'dropout_132[0][0]']
#
#  dropout_133 (Dropout)          (None, 19, 19, 512)  0           ['add_120[0][0]']
#
#  batch_normalization_382 (Batch  (None, 19, 19, 512)  2048       ['dropout_133[0][0]']
#  Normalization)
#
#  conv2d_391 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_382[0][0]']
#
#  activation_370 (Activation)    (None, 19, 19, 128)  0           ['conv2d_391[0][0]']
#
#  batch_normalization_383 (Batch  (None, 19, 19, 128)  512        ['activation_370[0][0]']
#  Normalization)
#
#  conv2d_392 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_383[0][0]']
#
#  activation_371 (Activation)    (None, 19, 19, 128)  0           ['conv2d_392[0][0]']
#
#  batch_normalization_384 (Batch  (None, 19, 19, 128)  512        ['activation_371[0][0]']
#  Normalization)
#
#  conv2d_393 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_384[0][0]']
#
#  activation_372 (Activation)    (None, 19, 19, 512)  0           ['conv2d_393[0][0]']
#
#  add_121 (Add)                  (None, 19, 19, 512)  0           ['activation_372[0][0]',
#                                                                   'dropout_133[0][0]']
#
#  dropout_134 (Dropout)          (None, 19, 19, 512)  0           ['add_121[0][0]']
#
#  batch_normalization_385 (Batch  (None, 19, 19, 512)  2048       ['dropout_134[0][0]']
#  Normalization)
#
#  conv2d_394 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_385[0][0]']
#
#  activation_373 (Activation)    (None, 19, 19, 128)  0           ['conv2d_394[0][0]']
#
#  batch_normalization_386 (Batch  (None, 19, 19, 128)  512        ['activation_373[0][0]']
#  Normalization)
#
#  conv2d_395 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_386[0][0]']
#
#  activation_374 (Activation)    (None, 19, 19, 128)  0           ['conv2d_395[0][0]']
#
#  batch_normalization_387 (Batch  (None, 19, 19, 128)  512        ['activation_374[0][0]']
#  Normalization)
#
#  conv2d_396 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_387[0][0]']
#
#  activation_375 (Activation)    (None, 19, 19, 512)  0           ['conv2d_396[0][0]']
#
#  add_122 (Add)                  (None, 19, 19, 512)  0           ['activation_375[0][0]',
#                                                                   'dropout_134[0][0]']
#
#  dropout_135 (Dropout)          (None, 19, 19, 512)  0           ['add_122[0][0]']
#
#  batch_normalization_388 (Batch  (None, 19, 19, 512)  2048       ['dropout_135[0][0]']
#  Normalization)
#
#  conv2d_397 (Conv2D)            (None, 19, 19, 128)  65536       ['batch_normalization_388[0][0]']
#
#  activation_376 (Activation)    (None, 19, 19, 128)  0           ['conv2d_397[0][0]']
#
#  batch_normalization_389 (Batch  (None, 19, 19, 128)  512        ['activation_376[0][0]']
#  Normalization)
#
#  conv2d_398 (Conv2D)            (None, 19, 19, 128)  147584      ['batch_normalization_389[0][0]']
#
#  activation_377 (Activation)    (None, 19, 19, 128)  0           ['conv2d_398[0][0]']
#
#  batch_normalization_390 (Batch  (None, 19, 19, 128)  512        ['activation_377[0][0]']
#  Normalization)
#
#  conv2d_399 (Conv2D)            (None, 19, 19, 512)  65536       ['batch_normalization_390[0][0]']
#
#  activation_378 (Activation)    (None, 19, 19, 512)  0           ['conv2d_399[0][0]']
#
#  add_123 (Add)                  (None, 19, 19, 512)  0           ['activation_378[0][0]',
#                                                                   'dropout_135[0][0]']
#
#  dropout_136 (Dropout)          (None, 19, 19, 512)  0           ['add_123[0][0]']
#
#  batch_normalization_391 (Batch  (None, 19, 19, 512)  2048       ['dropout_136[0][0]']
#  Normalization)
#
#  conv2d_400 (Conv2D)            (None, 9, 9, 256)    1179904     ['batch_normalization_391[0][0]']
#
#  dropout_137 (Dropout)          (None, 9, 9, 256)    0           ['conv2d_400[0][0]']
#
#  batch_normalization_392 (Batch  (None, 9, 9, 256)   1024        ['dropout_137[0][0]']
#  Normalization)
#
#  conv2d_401 (Conv2D)            (None, 9, 9, 256)    65536       ['batch_normalization_392[0][0]']
#
#  activation_379 (Activation)    (None, 9, 9, 256)    0           ['conv2d_401[0][0]']
#
#  batch_normalization_393 (Batch  (None, 9, 9, 256)   1024        ['activation_379[0][0]']
#  Normalization)
#
#  conv2d_402 (Conv2D)            (None, 9, 9, 256)    590080      ['batch_normalization_393[0][0]']
#
#  activation_380 (Activation)    (None, 9, 9, 256)    0           ['conv2d_402[0][0]']
#
#  batch_normalization_394 (Batch  (None, 9, 9, 256)   1024        ['activation_380[0][0]']
#  Normalization)
#
#  conv2d_403 (Conv2D)            (None, 9, 9, 1024)   262144      ['batch_normalization_394[0][0]']
#
#  activation_381 (Activation)    (None, 9, 9, 1024)   0           ['conv2d_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 9, 9, 1024)   262144      ['dropout_137[0][0]']
#
#  add_124 (Add)                  (None, 9, 9, 1024)   0           ['activation_381[0][0]',
#                                                                   'conv2d_404[0][0]']
#
#  dropout_138 (Dropout)          (None, 9, 9, 1024)   0           ['add_124[0][0]']
#
#  batch_normalization_395 (Batch  (None, 9, 9, 1024)  4096        ['dropout_138[0][0]']
#  Normalization)
#
#  conv2d_405 (Conv2D)            (None, 9, 9, 256)    262144      ['batch_normalization_395[0][0]']
#
#  activation_382 (Activation)    (None, 9, 9, 256)    0           ['conv2d_405[0][0]']
#
#  batch_normalization_396 (Batch  (None, 9, 9, 256)   1024        ['activation_382[0][0]']
#  Normalization)
#
#  conv2d_406 (Conv2D)            (None, 9, 9, 256)    590080      ['batch_normalization_396[0][0]']
#
#  activation_383 (Activation)    (None, 9, 9, 256)    0           ['conv2d_406[0][0]']
#
#  batch_normalization_397 (Batch  (None, 9, 9, 256)   1024        ['activation_383[0][0]']
# ...
#  conv2d_448 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_437[0][0]']
#
#  activation_423 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_448[0][0]']
#
#  add_138 (Add)                  (None, 4, 4, 1024)   0           ['activation_423[0][0]',
#                                                                   'dropout_152[0][0]']
#
#  dropout_153 (Dropout)          (None, 4, 4, 1024)   0           ['add_138[0][0]']
#
#  batch_normalization_438 (Batch  (None, 4, 4, 1024)  4096        ['dropout_153[0][0]']
#  Normalization)
#
#  conv2d_449 (Conv2D)            (None, 4, 4, 256)    262144      ['batch_normalization_438[0][0]']
#
#  activation_424 (Activation)    (None, 4, 4, 256)    0           ['conv2d_449[0][0]']
#
#  batch_normalization_439 (Batch  (None, 4, 4, 256)   1024        ['activation_424[0][0]']
#  Normalization)
#
#  conv2d_450 (Conv2D)            (None, 4, 4, 256)    590080      ['batch_normalization_439[0][0]']
#
#  activation_425 (Activation)    (None, 4, 4, 256)    0           ['conv2d_450[0][0]']
#
#  batch_normalization_440 (Batch  (None, 4, 4, 256)   1024        ['activation_425[0][0]']
#  Normalization)
#
#  conv2d_451 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_440[0][0]']
#
#  activation_426 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_451[0][0]']
#
#  add_139 (Add)                  (None, 4, 4, 1024)   0           ['activation_426[0][0]',
#                                                                   'dropout_153[0][0]']
#
#  dropout_154 (Dropout)          (None, 4, 4, 1024)   0           ['add_139[0][0]']
#
#  batch_normalization_441 (Batch  (None, 4, 4, 1024)  4096        ['dropout_154[0][0]']
#  Normalization)
#
#  conv2d_452 (Conv2D)            (None, 4, 4, 256)    262144      ['batch_normalization_441[0][0]']
#
#  activation_427 (Activation)    (None, 4, 4, 256)    0           ['conv2d_452[0][0]']
#
#  batch_normalization_442 (Batch  (None, 4, 4, 256)   1024        ['activation_427[0][0]']
#  Normalization)
#
#  conv2d_453 (Conv2D)            (None, 4, 4, 256)    590080      ['batch_normalization_442[0][0]']
#
#  activation_428 (Activation)    (None, 4, 4, 256)    0           ['conv2d_453[0][0]']
#
#  batch_normalization_443 (Batch  (None, 4, 4, 256)   1024        ['activation_428[0][0]']
#  Normalization)
#
#  conv2d_454 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_443[0][0]']
#
#  activation_429 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_454[0][0]']
#
#  add_140 (Add)                  (None, 4, 4, 1024)   0           ['activation_429[0][0]',
#                                                                   'dropout_154[0][0]']
#
#  dropout_155 (Dropout)          (None, 4, 4, 1024)   0           ['add_140[0][0]']
#
#  batch_normalization_444 (Batch  (None, 4, 4, 1024)  4096        ['dropout_155[0][0]']
#  Normalization)
#
#  conv2d_455 (Conv2D)            (None, 4, 4, 256)    262144      ['batch_normalization_444[0][0]']
#
#  activation_430 (Activation)    (None, 4, 4, 256)    0           ['conv2d_455[0][0]']
#
#  batch_normalization_445 (Batch  (None, 4, 4, 256)   1024        ['activation_430[0][0]']
#  Normalization)
#
#  conv2d_456 (Conv2D)            (None, 4, 4, 256)    590080      ['batch_normalization_445[0][0]']
#
#  activation_431 (Activation)    (None, 4, 4, 256)    0           ['conv2d_456[0][0]']
#
#  batch_normalization_446 (Batch  (None, 4, 4, 256)   1024        ['activation_431[0][0]']
#  Normalization)
#
#  conv2d_457 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_446[0][0]']
#
#  activation_432 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_457[0][0]']
#
#  add_141 (Add)                  (None, 4, 4, 1024)   0           ['activation_432[0][0]',
#                                                                   'dropout_155[0][0]']
#
#  dropout_156 (Dropout)          (None, 4, 4, 1024)   0           ['add_141[0][0]']
#
#  batch_normalization_447 (Batch  (None, 4, 4, 1024)  4096        ['dropout_156[0][0]']
#  Normalization)
#
#  conv2d_458 (Conv2D)            (None, 4, 4, 256)    262144      ['batch_normalization_447[0][0]']
#
#  activation_433 (Activation)    (None, 4, 4, 256)    0           ['conv2d_458[0][0]']
#
#  batch_normalization_448 (Batch  (None, 4, 4, 256)   1024        ['activation_433[0][0]']
#  Normalization)
#
#  conv2d_459 (Conv2D)            (None, 4, 4, 256)    590080      ['batch_normalization_448[0][0]']
#
#  activation_434 (Activation)    (None, 4, 4, 256)    0           ['conv2d_459[0][0]']
#
#  batch_normalization_449 (Batch  (None, 4, 4, 256)   1024        ['activation_434[0][0]']
#  Normalization)
#
#  conv2d_460 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_449[0][0]']
#
#  activation_435 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_460[0][0]']
#
#  add_142 (Add)                  (None, 4, 4, 1024)   0           ['activation_435[0][0]',
#                                                                   'dropout_156[0][0]']
#
#  dropout_157 (Dropout)          (None, 4, 4, 1024)   0           ['add_142[0][0]']
#
#  batch_normalization_450 (Batch  (None, 4, 4, 1024)  4096        ['dropout_157[0][0]']
#  Normalization)
#
#  conv2d_461 (Conv2D)            (None, 4, 4, 256)    262144      ['batch_normalization_450[0][0]']
#
#  activation_436 (Activation)    (None, 4, 4, 256)    0           ['conv2d_461[0][0]']
#
#  batch_normalization_451 (Batch  (None, 4, 4, 256)   1024        ['activation_436[0][0]']
#  Normalization)
#
#  conv2d_462 (Conv2D)            (None, 4, 4, 256)    590080      ['batch_normalization_451[0][0]']
#
#  activation_437 (Activation)    (None, 4, 4, 256)    0           ['conv2d_462[0][0]']
#
#  batch_normalization_452 (Batch  (None, 4, 4, 256)   1024        ['activation_437[0][0]']
#  Normalization)
#
#  conv2d_463 (Conv2D)            (None, 4, 4, 1024)   262144      ['batch_normalization_452[0][0]']
#
#  activation_438 (Activation)    (None, 4, 4, 1024)   0           ['conv2d_463[0][0]']
#
#  add_143 (Add)                  (None, 4, 4, 1024)   0           ['activation_438[0][0]',
#                                                                   'dropout_157[0][0]']
#
#  dropout_158 (Dropout)          (None, 4, 4, 1024)   0           ['add_143[0][0]']
#
#  batch_normalization_453 (Batch  (None, 4, 4, 1024)  4096        ['dropout_158[0][0]']
#  Normalization)
#
#  global_average_pooling2d_3 (Gl  (None, 1024)        0           ['batch_normalization_453[0][0]']
#  obalAveragePooling2D)
#
#  dropout_159 (Dropout)          (None, 1024)         0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  batch_normalization_454 (Batch  (None, 1024)        4096        ['dropout_159[0][0]']
#  Normalization)
#
#  dense_6 (Dense)                (None, 512)          524800      ['batch_normalization_454[0][0]']
#
#  activation_439 (Activation)    (None, 512)          0           ['dense_6[0][0]']
#
#  batch_normalization_455 (Batch  (None, 512)         2048        ['activation_439[0][0]']
#  Normalization)
#
#  dense_7 (Dense)                (None, 6)            3078        ['batch_normalization_455[0][0]']
# ==================================================================================================
# Total params: 35,195,398
# Trainable params: 35,104,006
# Non-trainable params: 91,392
# __________________________________________________________________________________________________
# None

# %%
evaluate(model)
# Out:
# --------------Make Predictions--------------
# Testing for training data
# 18/18 [==============================] - 118s 6s/step
# Testing time (s) = 122.64019659999758
#
# Confusion matrix =
# [[94  0  0  1  1  0]
#  [ 0 91  1  1  0  3]
#  [ 0  1 93  0  2  0]
#  [ 0  0  0 95  1  0]
#  [ 0  2  3  0 91  0]
#  [ 1  0  0  1  0 94]]
# ---------------------------------------------
# Testing for test data
# 5/5 [==============================] - 31s 5s/step
# Testing time (s) = 31.663847399991937
#
# Confusion matrix =
# [[ 6  5  5  1  5  2]
#  [ 4  2  7  6  3  2]
#  [ 3  4  6  3  5  3]
#  [ 2  4  3 11  2  2]
#  [ 4  2  4  3  8  3]
#  [ 3  6  4  6  0  5]]
